# %%
import tweepy
from tweepy import OAuthHandler
 
consumer_key = '<consumerkey>'
consumer_secret = '<consumersecret>'
access_token = '<your-access-token'
access_secret = '<your-access-secret'
 
auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)
 
api = tweepy.API(auth)

# %%
for status in tweepy.Cursor(api.home_timeline).items(10):
    # Process a single status
    print(status.text)
# Out:
# Ok we’re hitting lending apocalypse in @peakbengaluru https://t.co/h4fHPclAE5
# RT @digiitsindia: The Best Big Data Seminars to Attend Powered by Data Science Council of America https://t.co/ixp8UKvkod https://t.co/SM9g…
# RT @digiitsblog: The Best Big Data Seminars to Attend Powered by Data Science Council of America https://t.co/gFcIbz8B7r https://t.co/hNkoU…
# RT @GlowLead: GlowLead is a leading UK company. Our services include Software and Webapp Development, Data Science,  consultancy in Busines…
# RT @curated_data: "If you cannot measure, then your knowledge is meager and unsatisfactory." — Lord Kelvin's dictum. #quote #inspiration #i…
# RT @ptbrdslinks: Data Science Links 16/02 (Last Message ID: 108183)
# RT @Nitish__Gautam: Regressive has nothing to do with it.
#
# It's all science(psychology) &amp; Maths(data).
#
# Hoping you won't further call any p…
# RT @ericdebray: Qu’est-ce qu’un site sait de vous lorsque vous surfez ? #dataprivacy #rgpd  https://t.co/4pO1uBgLWv #cybersécurité
# RT @AllysonTowle: #AppSec
# #SecOps
# #Zero Trust
# #DataPrivacy
# Next Gen #SOC
# #DataGovernance
# #MachineLearning...
# Just a sampling of the sessi…
# RT @unknownbyDream: besook guyss besookk
# Ga sabarrr akuuu 😭😭😭😭 baru x ini nunggu cb idol greget, gemesss, deg2an 😭😭dahlah #Dystopia #Dystop…

# %%
for status in tweepy.Cursor(api.home_timeline).items(10):
    # Process a single status
    print(status._json)
# Out:
# {'created_at': 'Mon Feb 17 06:50:57 +0000 2020', 'id': 1229297163387031552, 'id_str': '1229297163387031552', 'text': 'Ok we’re hitting lending apocalypse in @peakbengaluru https://t.co/h4fHPclAE5', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'peakbengaluru', 'name': 'Peak Bengaluru', 'id': 956466499325116416, 'id_str': '956466499325116416', 'indices': [39, 53]}], 'urls': [{'url': 'https://t.co/h4fHPclAE5', 'expanded_url': 'https://twitter.com/PaladinContent/status/1229277622128930817', 'display_url': 'twitter.com/PaladinContent…', 'indices': [54, 77]}]}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 956466499325116416, 'id_str': '956466499325116416', 'name': 'Peak Bengaluru', 'screen_name': 'peakbengaluru', 'location': 'Koramangala🛴HSR🛴Indiranagar', 'description': 'Startup-tech-hipster frenzy from namma bengaluru! 🚀🦄 \n\nSpotted anything interesting? Tweet @peakbengaluru', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 6421, 'friends_count': 38, 'listed_count': 25, 'created_at': 'Thu Jan 25 09:59:18 +0000 2018', 'favourites_count': 1393, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 1138, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1202910555633278976/7uRuoz0G_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1202910555633278976/7uRuoz0G_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/956466499325116416/1566990941', 'profile_link_color': '981CEB', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': True, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': True, 'quoted_status_id': 1229277622128930817, 'quoted_status_id_str': '1229277622128930817', 'quoted_status': {'created_at': 'Mon Feb 17 05:33:18 +0000 2020', 'id': 1229277622128930817, 'id_str': '1229277622128930817', 'text': 'ok bro 😔 https://t.co/KmKBYQqXAi', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [], 'media': [{'id': 1229277606257709056, 'id_str': '1229277606257709056', 'indices': [9, 32], 'media_url': 'http://pbs.twimg.com/media/EQ9FeEtVUAArr3s.jpg', 'media_url_https': 'https://pbs.twimg.com/media/EQ9FeEtVUAArr3s.jpg', 'url': 'https://t.co/KmKBYQqXAi', 'display_url': 'pic.twitter.com/KmKBYQqXAi', 'expanded_url': 'https://twitter.com/PaladinContent/status/1229277622128930817/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'large': {'w': 1536, 'h': 2048, 'resize': 'fit'}, 'medium': {'w': 900, 'h': 1200, 'resize': 'fit'}, 'small': {'w': 510, 'h': 680, 'resize': 'fit'}}}]}, 'extended_entities': {'media': [{'id': 1229277606257709056, 'id_str': '1229277606257709056', 'indices': [9, 32], 'media_url': 'http://pbs.twimg.com/media/EQ9FeEtVUAArr3s.jpg', 'media_url_https': 'https://pbs.twimg.com/media/EQ9FeEtVUAArr3s.jpg', 'url': 'https://t.co/KmKBYQqXAi', 'display_url': 'pic.twitter.com/KmKBYQqXAi', 'expanded_url': 'https://twitter.com/PaladinContent/status/1229277622128930817/photo/1', 'type': 'photo',  ...
# {'created_at': 'Mon Feb 17 06:47:43 +0000 2020', 'id': 1229296349683818497, 'id_str': '1229296349683818497', 'text': 'RT @digiitsindia: The Best Big Data Seminars to Attend Powered by Data Science Council of\xa0America https://t.co/ixp8UKvkod https://t.co/SM9g…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'digiitsindia', 'name': 'Digiit Solutions', 'id': 1700212165, 'id_str': '1700212165', 'indices': [3, 16]}], 'urls': [{'url': 'https://t.co/ixp8UKvkod', 'expanded_url': 'https://www.spokenbyyou.com/the-best-big-data-seminars-to-attend-powered-by-data-science-council-of-america/', 'display_url': 'spokenbyyou.com/the-best-big-d…', 'indices': [98, 121]}]}, 'source': '<a href="http://www.insomniachat.com" rel="nofollow">spoken word vincent</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 19539923, 'id_str': '19539923', 'name': 'dystopian mentalist', 'screen_name': 'JustBeMentalist', 'location': 'Shropshire', 'description': 'irreverent Mentalist: Behavioral Data hActivist, investigative writer monitoring data-driven political & social PsyOPs #dataprivacy protect Animal/Human Rights', 'url': 'https://t.co/yabJ8OlEQw', 'entities': {'url': {'urls': [{'url': 'https://t.co/yabJ8OlEQw', 'expanded_url': 'http://sleeplessdystopian.com', 'display_url': 'sleeplessdystopian.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 3153, 'friends_count': 1125, 'listed_count': 123, 'created_at': 'Mon Jan 26 15:43:29 +0000 2009', 'favourites_count': 377, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 191101, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '1A1B1F', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/687359419282239488/-12hV0wh_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/687359419282239488/-12hV0wh_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/19539923/1433070750', 'profile_link_color': '2FC2EF', 'profile_sidebar_border_color': '181A1E', 'profile_sidebar_fill_color': '252429', 'profile_text_color': '666666', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': True, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Mon Feb 17 06:47:09 +0000 2020', 'id': 1229296207119470593, 'id_str': '1229296207119470593', 'text': 'The Best Big Data Seminars to Attend Powered by Data Science Council of\xa0America https://t.co/ixp8UKvkod https://t.co/SM9g2eafij', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/ixp8UKvkod', 'expanded_url': 'https://www.spokenbyyou.com/the-best-big-data-seminars-to-attend-powered-by-data-science-council-of-america/', 'display_url': 'spokenbyyou.com/the-best-big-d…', 'indices': [80, 103]}], 'media': [{'id': 1229296205261410304, 'id_str': '1229296205261410304', 'indices': [104, 127], 'media_url': 'http://pbs.twimg.com/media/EQ9WYrZXkAAd0Tw.jpg', 'media_url_https': 'https://pbs.twimg.com/media/EQ9WYrZXkAAd0Tw.jpg', 'url': 'https://t.co/SM9g2eafij', 'display_url': 'pic.twitter.com/SM9g2eafij', 'expanded_url': 'https://twitter.com/digiitsindia/status/1229296207119470593/photo/1', 'type': 'photo', 'sizes': {'small': {'w': 628, 'h': 407, 'resize': 'fit'}, 'large': {'w': 628, 'h': 407, 'resize': 'fit'}, 'thumb' ...
# {'created_at': 'Mon Feb 17 06:47:41 +0000 2020', 'id': 1229296340762578944, 'id_str': '1229296340762578944', 'text': 'RT @digiitsblog: The Best Big Data Seminars to Attend Powered by Data Science Council of\xa0America https://t.co/gFcIbz8B7r https://t.co/hNkoU…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'digiitsblog', 'name': 'Spoken by You', 'id': 3182183810, 'id_str': '3182183810', 'indices': [3, 15]}], 'urls': [{'url': 'https://t.co/gFcIbz8B7r', 'expanded_url': 'https://www.spokenbyyou.com/the-best-big-data-seminars-to-attend-powered-by-data-science-council-of-america/', 'display_url': 'spokenbyyou.com/the-best-big-d…', 'indices': [97, 120]}]}, 'source': '<a href="http://www.insomniachat.com" rel="nofollow">spoken word vincent</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 19539923, 'id_str': '19539923', 'name': 'dystopian mentalist', 'screen_name': 'JustBeMentalist', 'location': 'Shropshire', 'description': 'irreverent Mentalist: Behavioral Data hActivist, investigative writer monitoring data-driven political & social PsyOPs #dataprivacy protect Animal/Human Rights', 'url': 'https://t.co/yabJ8OlEQw', 'entities': {'url': {'urls': [{'url': 'https://t.co/yabJ8OlEQw', 'expanded_url': 'http://sleeplessdystopian.com', 'display_url': 'sleeplessdystopian.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 3153, 'friends_count': 1125, 'listed_count': 123, 'created_at': 'Mon Jan 26 15:43:29 +0000 2009', 'favourites_count': 377, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 191101, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '1A1B1F', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/687359419282239488/-12hV0wh_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/687359419282239488/-12hV0wh_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/19539923/1433070750', 'profile_link_color': '2FC2EF', 'profile_sidebar_border_color': '181A1E', 'profile_sidebar_fill_color': '252429', 'profile_text_color': '666666', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': True, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Mon Feb 17 06:47:07 +0000 2020', 'id': 1229296197988421634, 'id_str': '1229296197988421634', 'text': 'The Best Big Data Seminars to Attend Powered by Data Science Council of\xa0America https://t.co/gFcIbz8B7r https://t.co/hNkoUwGOVC', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/gFcIbz8B7r', 'expanded_url': 'https://www.spokenbyyou.com/the-best-big-data-seminars-to-attend-powered-by-data-science-council-of-america/', 'display_url': 'spokenbyyou.com/the-best-big-d…', 'indices': [80, 103]}], 'media': [{'id': 1229296196511989760, 'id_str': '1229296196511989760', 'indices': [104, 127], 'media_url': 'http://pbs.twimg.com/media/EQ9WYKzWAAAIR8P.jpg', 'media_url_https': 'https://pbs.twimg.com/media/EQ9WYKzWAAAIR8P.jpg', 'url': 'https://t.co/hNkoUwGOVC', 'display_url': 'pic.twitter.com/hNkoUwGOVC', 'expanded_url': 'https://twitter.com/digiitsblog/status/1229296197988421634/photo/1', 'type': 'photo', 'sizes': {'small': {'w': 628, 'h': 407, 'resize': 'fit'}, 'large': {'w': 628, 'h': 407, 'resize': 'fit'}, 'thumb': {'w ...
# {'created_at': 'Mon Feb 17 06:47:39 +0000 2020', 'id': 1229296331908435969, 'id_str': '1229296331908435969', 'text': 'RT @GlowLead: GlowLead is a leading UK company. Our services include Software and Webapp Development, Data Science,  consultancy in Busines…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'GlowLead', 'name': 'GlowLead', 'id': 1218499229095800832, 'id_str': '1218499229095800832', 'indices': [3, 12]}], 'urls': []}, 'source': '<a href="http://www.insomniachat.com" rel="nofollow">spoken word vincent</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 19539923, 'id_str': '19539923', 'name': 'dystopian mentalist', 'screen_name': 'JustBeMentalist', 'location': 'Shropshire', 'description': 'irreverent Mentalist: Behavioral Data hActivist, investigative writer monitoring data-driven political & social PsyOPs #dataprivacy protect Animal/Human Rights', 'url': 'https://t.co/yabJ8OlEQw', 'entities': {'url': {'urls': [{'url': 'https://t.co/yabJ8OlEQw', 'expanded_url': 'http://sleeplessdystopian.com', 'display_url': 'sleeplessdystopian.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 3153, 'friends_count': 1125, 'listed_count': 123, 'created_at': 'Mon Jan 26 15:43:29 +0000 2009', 'favourites_count': 377, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 191101, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '1A1B1F', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/687359419282239488/-12hV0wh_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/687359419282239488/-12hV0wh_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/19539923/1433070750', 'profile_link_color': '2FC2EF', 'profile_sidebar_border_color': '181A1E', 'profile_sidebar_fill_color': '252429', 'profile_text_color': '666666', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': True, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Mon Feb 17 06:45:41 +0000 2020', 'id': 1229295838725320706, 'id_str': '1229295838725320706', 'text': 'GlowLead is a leading UK company. Our services include Software and Webapp Development, Data Science,  consultancy… https://t.co/iuWu7zISlQ', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/iuWu7zISlQ', 'expanded_url': 'https://twitter.com/i/web/status/1229295838725320706', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [116, 139]}]}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1218499229095800832, 'id_str': '1218499229095800832', 'name': 'GlowLead', 'screen_name': 'GlowLead', 'location': '', 'description': 'GlowLead is a group of experts, Developers, Data Scientists, & Consultants you can trust.  visit our website: https://t.co/rKivt4y18n', 'url': None, 'entities': {'description': {'urls': [{'url': 'https://t.co/rKivt4y18n', 'expanded_url': 'http://www.glowlead.com', 'display_url': 'glowlead.com', 'indices': [110, 133]}]}}, 'protected': False, 'followers_count': 74, 'friends_count': 820, 'listed_count': 0, 'cr ...
# {'created_at': 'Mon Feb 17 06:47:37 +0000 2020', 'id': 1229296323024826371, 'id_str': '1229296323024826371', 'text': 'RT @curated_data: "If you cannot measure, then your knowledge is meager and unsatisfactory." — Lord Kelvin\'s dictum. #quote #inspiration #i…', 'truncated': False, 'entities': {'hashtags': [{'text': 'quote', 'indices': [117, 123]}, {'text': 'inspiration', 'indices': [124, 136]}], 'symbols': [], 'user_mentions': [{'screen_name': 'curated_data', 'name': 'DataScienceCurator', 'id': 939060292008468480, 'id_str': '939060292008468480', 'indices': [3, 16]}], 'urls': []}, 'source': '<a href="http://www.insomniachat.com" rel="nofollow">spoken word vincent</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 19539923, 'id_str': '19539923', 'name': 'dystopian mentalist', 'screen_name': 'JustBeMentalist', 'location': 'Shropshire', 'description': 'irreverent Mentalist: Behavioral Data hActivist, investigative writer monitoring data-driven political & social PsyOPs #dataprivacy protect Animal/Human Rights', 'url': 'https://t.co/yabJ8OlEQw', 'entities': {'url': {'urls': [{'url': 'https://t.co/yabJ8OlEQw', 'expanded_url': 'http://sleeplessdystopian.com', 'display_url': 'sleeplessdystopian.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 3153, 'friends_count': 1125, 'listed_count': 123, 'created_at': 'Mon Jan 26 15:43:29 +0000 2009', 'favourites_count': 377, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 191101, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '1A1B1F', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/687359419282239488/-12hV0wh_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/687359419282239488/-12hV0wh_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/19539923/1433070750', 'profile_link_color': '2FC2EF', 'profile_sidebar_border_color': '181A1E', 'profile_sidebar_fill_color': '252429', 'profile_text_color': '666666', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': True, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Mon Feb 17 06:45:18 +0000 2020', 'id': 1229295740708696064, 'id_str': '1229295740708696064', 'text': '"If you cannot measure, then your knowledge is meager and unsatisfactory." — Lord Kelvin\'s dictum. #quote #inspiration #inspiring #science', 'truncated': False, 'entities': {'hashtags': [{'text': 'quote', 'indices': [99, 105]}, {'text': 'inspiration', 'indices': [106, 118]}, {'text': 'inspiring', 'indices': [119, 129]}, {'text': 'science', 'indices': [130, 138]}], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="https://www.data-blogger.com/" rel="nofollow">TweetFeedDataBlogger</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 939060292008468480, 'id_str': '939060292008468480', 'name': 'DataScienceCurator', 'screen_name': 'curated_data', 'location': '127.0.0.1', 'description': 'A curated collection of recent Artificial Intelligence, Data Science and Machine Learning blog posts and scientific quotes.', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 462, 'friends_count': 41, 'listed_count': 15, 'created_a ...
# {'created_at': 'Mon Feb 17 06:47:28 +0000 2020', 'id': 1229296287759159296, 'id_str': '1229296287759159296', 'text': 'RT @ptbrdslinks: Data Science Links 16/02 (Last Message ID: 108183)', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'ptbrdslinks', 'name': 'Pt-BR Data Science Links', 'id': 1185823064774397953, 'id_str': '1185823064774397953', 'indices': [3, 15]}], 'urls': []}, 'source': '<a href="http://www.insomniachat.com" rel="nofollow">spoken word vincent</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 19539923, 'id_str': '19539923', 'name': 'dystopian mentalist', 'screen_name': 'JustBeMentalist', 'location': 'Shropshire', 'description': 'irreverent Mentalist: Behavioral Data hActivist, investigative writer monitoring data-driven political & social PsyOPs #dataprivacy protect Animal/Human Rights', 'url': 'https://t.co/yabJ8OlEQw', 'entities': {'url': {'urls': [{'url': 'https://t.co/yabJ8OlEQw', 'expanded_url': 'http://sleeplessdystopian.com', 'display_url': 'sleeplessdystopian.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 3153, 'friends_count': 1125, 'listed_count': 123, 'created_at': 'Mon Jan 26 15:43:29 +0000 2009', 'favourites_count': 377, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 191101, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '1A1B1F', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/687359419282239488/-12hV0wh_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/687359419282239488/-12hV0wh_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/19539923/1433070750', 'profile_link_color': '2FC2EF', 'profile_sidebar_border_color': '181A1E', 'profile_sidebar_fill_color': '252429', 'profile_text_color': '666666', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': True, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Mon Feb 17 06:44:53 +0000 2020', 'id': 1229295635154841600, 'id_str': '1229295635154841600', 'text': 'Data Science Links 16/02 (Last Message ID: 108183)', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="https://t.me/datasciencepython" rel="nofollow">Pt-BR Data Science Links</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1185823064774397953, 'id_str': '1185823064774397953', 'name': 'Pt-BR Data Science Links', 'screen_name': 'ptbrdslinks', 'location': '', 'description': 'Scrapping de links da comunidade Pt-BR Data Science no Telegram https://t.co/S89Kkana46', 'url': None, 'entities': {'description': {'urls': [{'url': 'https://t.co/S89Kkana46', 'expanded_url': 'https://t.me/datasciencepython', 'display_url': 't.me/datasciencepyt…', 'indices': [64, 87]}]}}, 'protected': False, 'followers_count': 20, 'friends_count': 0, 'listed_count': 0, 'created_at': 'Sun Oct 20 07:40:33 +0000 2019', 'favourites_count': 0, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 776, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_ ...
# {'created_at': 'Mon Feb 17 06:47:24 +0000 2020', 'id': 1229296270122065921, 'id_str': '1229296270122065921', 'text': "RT @Nitish__Gautam: Regressive has nothing to do with it.\n\nIt's all science(psychology) &amp; Maths(data).\n\nHoping you won't further call any p…", 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'Nitish__Gautam', 'name': 'Nitish Gautam', 'id': 1071120423515877376, 'id_str': '1071120423515877376', 'indices': [3, 18]}], 'urls': []}, 'source': '<a href="http://www.insomniachat.com" rel="nofollow">spoken word vincent</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 19539923, 'id_str': '19539923', 'name': 'dystopian mentalist', 'screen_name': 'JustBeMentalist', 'location': 'Shropshire', 'description': 'irreverent Mentalist: Behavioral Data hActivist, investigative writer monitoring data-driven political & social PsyOPs #dataprivacy protect Animal/Human Rights', 'url': 'https://t.co/yabJ8OlEQw', 'entities': {'url': {'urls': [{'url': 'https://t.co/yabJ8OlEQw', 'expanded_url': 'http://sleeplessdystopian.com', 'display_url': 'sleeplessdystopian.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 3153, 'friends_count': 1125, 'listed_count': 123, 'created_at': 'Mon Jan 26 15:43:29 +0000 2009', 'favourites_count': 377, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 191101, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '1A1B1F', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/687359419282239488/-12hV0wh_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/687359419282239488/-12hV0wh_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/19539923/1433070750', 'profile_link_color': '2FC2EF', 'profile_sidebar_border_color': '181A1E', 'profile_sidebar_fill_color': '252429', 'profile_text_color': '666666', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': True, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Mon Feb 17 06:44:27 +0000 2020', 'id': 1229295526178222081, 'id_str': '1229295526178222081', 'text': "Regressive has nothing to do with it.\n\nIt's all science(psychology) &amp; Maths(data).\n\nHoping you won't further call a… https://t.co/jXeCMRJG59", 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/jXeCMRJG59', 'expanded_url': 'https://twitter.com/i/web/status/1229295526178222081', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [121, 144]}]}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1071120423515877376, 'id_str': '1071120423515877376', 'name': 'Nitish Gautam', 'screen_name': 'Nitish__Gautam', 'location': '', 'description': 'Sanatani - Atom - Life - Animal - Sapiens - Male', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 57, 'friends_count': 185, 'listed_count': 0, 'created_at': 'Fri Dec 07 19:13:04 +0000 2018', 'favourites_count': 17696, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_co ...
# {'created_at': 'Mon Feb 17 06:47:20 +0000 2020', 'id': 1229296253340614657, 'id_str': '1229296253340614657', 'text': 'RT @ericdebray: Qu’est-ce qu’un site sait de vous lorsque vous surfez ? #dataprivacy #rgpd  https://t.co/4pO1uBgLWv #cybersécurité', 'truncated': False, 'entities': {'hashtags': [{'text': 'dataprivacy', 'indices': [72, 84]}, {'text': 'rgpd', 'indices': [85, 90]}, {'text': 'cybersécurité', 'indices': [116, 130]}], 'symbols': [], 'user_mentions': [{'screen_name': 'ericdebray', 'name': 'Eric Debray', 'id': 247315084, 'id_str': '247315084', 'indices': [3, 14]}], 'urls': [{'url': 'https://t.co/4pO1uBgLWv', 'expanded_url': 'https://buff.ly/2SuKrCQ', 'display_url': 'buff.ly/2SuKrCQ', 'indices': [92, 115]}]}, 'source': '<a href="http://www.insomniachat.com" rel="nofollow">spoken word vincent</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 19539923, 'id_str': '19539923', 'name': 'dystopian mentalist', 'screen_name': 'JustBeMentalist', 'location': 'Shropshire', 'description': 'irreverent Mentalist: Behavioral Data hActivist, investigative writer monitoring data-driven political & social PsyOPs #dataprivacy protect Animal/Human Rights', 'url': 'https://t.co/yabJ8OlEQw', 'entities': {'url': {'urls': [{'url': 'https://t.co/yabJ8OlEQw', 'expanded_url': 'http://sleeplessdystopian.com', 'display_url': 'sleeplessdystopian.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 3153, 'friends_count': 1125, 'listed_count': 123, 'created_at': 'Mon Jan 26 15:43:29 +0000 2009', 'favourites_count': 377, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 191101, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '1A1B1F', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/687359419282239488/-12hV0wh_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/687359419282239488/-12hV0wh_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/19539923/1433070750', 'profile_link_color': '2FC2EF', 'profile_sidebar_border_color': '181A1E', 'profile_sidebar_fill_color': '252429', 'profile_text_color': '666666', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': True, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Mon Feb 17 06:40:11 +0000 2020', 'id': 1229294453917126661, 'id_str': '1229294453917126661', 'text': 'Qu’est-ce qu’un site sait de vous lorsque vous surfez ? #dataprivacy #rgpd  https://t.co/4pO1uBgLWv #cybersécurité', 'truncated': False, 'entities': {'hashtags': [{'text': 'dataprivacy', 'indices': [56, 68]}, {'text': 'rgpd', 'indices': [69, 74]}, {'text': 'cybersécurité', 'indices': [100, 114]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/4pO1uBgLWv', 'expanded_url': 'https://buff.ly/2SuKrCQ', 'display_url': 'buff.ly/2SuKrCQ', 'indices': [76, 99]}]}, 'source': '<a href="https://buffer.com" rel="nofollow">Buffer</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 247315084, 'id_str': '247315084', 'name': 'Eric Debray', 'screen_name': 'ericdebray', 'location': 'Paris, Villefranche sur mer', 'description': '#numerique , #cloud, #BigData, #IoT, #IA , #cybersecurité ...conseil en communication & strategie digitale : ...
# {'created_at': 'Mon Feb 17 06:47:11 +0000 2020', 'id': 1229296215076089858, 'id_str': '1229296215076089858', 'text': 'RT @AllysonTowle: #AppSec\n#SecOps\n#Zero Trust\n#DataPrivacy \nNext Gen #SOC\n#DataGovernance \n#MachineLearning...\nJust a sampling of the sessi…', 'truncated': False, 'entities': {'hashtags': [{'text': 'AppSec', 'indices': [18, 25]}, {'text': 'SecOps', 'indices': [26, 33]}, {'text': 'Zero', 'indices': [34, 39]}, {'text': 'DataPrivacy', 'indices': [46, 58]}, {'text': 'SOC', 'indices': [69, 73]}, {'text': 'DataGovernance', 'indices': [74, 89]}, {'text': 'MachineLearning', 'indices': [91, 107]}], 'symbols': [], 'user_mentions': [{'screen_name': 'AllysonTowle', 'name': 'Allyson Towle', 'id': 3021254723, 'id_str': '3021254723', 'indices': [3, 16]}], 'urls': []}, 'source': '<a href="http://www.insomniachat.com" rel="nofollow">spoken word vincent</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 19539923, 'id_str': '19539923', 'name': 'dystopian mentalist', 'screen_name': 'JustBeMentalist', 'location': 'Shropshire', 'description': 'irreverent Mentalist: Behavioral Data hActivist, investigative writer monitoring data-driven political & social PsyOPs #dataprivacy protect Animal/Human Rights', 'url': 'https://t.co/yabJ8OlEQw', 'entities': {'url': {'urls': [{'url': 'https://t.co/yabJ8OlEQw', 'expanded_url': 'http://sleeplessdystopian.com', 'display_url': 'sleeplessdystopian.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 3153, 'friends_count': 1125, 'listed_count': 123, 'created_at': 'Mon Jan 26 15:43:29 +0000 2009', 'favourites_count': 377, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 191101, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '1A1B1F', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/687359419282239488/-12hV0wh_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/687359419282239488/-12hV0wh_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/19539923/1433070750', 'profile_link_color': '2FC2EF', 'profile_sidebar_border_color': '181A1E', 'profile_sidebar_fill_color': '252429', 'profile_text_color': '666666', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': True, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Mon Feb 17 06:37:08 +0000 2020', 'id': 1229293686766235649, 'id_str': '1229293686766235649', 'text': '#AppSec\n#SecOps\n#Zero Trust\n#DataPrivacy \nNext Gen #SOC\n#DataGovernance \n#MachineLearning...\nJust a sampling of the… https://t.co/SxCDHJo8Wn', 'truncated': True, 'entities': {'hashtags': [{'text': 'AppSec', 'indices': [0, 7]}, {'text': 'SecOps', 'indices': [8, 15]}, {'text': 'Zero', 'indices': [16, 21]}, {'text': 'DataPrivacy', 'indices': [28, 40]}, {'text': 'SOC', 'indices': [51, 55]}, {'text': 'DataGovernance', 'indices': [56, 71]}, {'text': 'MachineLearning', 'indices': [73, 89]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/SxCDHJo8Wn', 'expanded_url': 'https://twitter.com/i/web/status/1229293686766235649', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'source': '<a href="http://www.everyonesocial.com" rel="nofollow">EveryoneSocial</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_u ...
# {'created_at': 'Mon Feb 17 06:47:08 +0000 2020', 'id': 1229296203600482304, 'id_str': '1229296203600482304', 'text': 'RT @unknownbyDream: besook guyss besookk\nGa sabarrr akuuu 😭😭😭😭 baru x ini nunggu cb idol greget, gemesss, deg2an 😭😭dahlah #Dystopia #Dystop…', 'truncated': False, 'entities': {'hashtags': [{'text': 'Dystopia', 'indices': [122, 131]}], 'symbols': [], 'user_mentions': [{'screen_name': 'unknownbyDream', 'name': 'Woopsiesss 💢', 'id': 1211448914919882752, 'id_str': '1211448914919882752', 'indices': [3, 18]}], 'urls': []}, 'source': '<a href="http://www.insomniachat.com" rel="nofollow">spoken word vincent</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 19539923, 'id_str': '19539923', 'name': 'dystopian mentalist', 'screen_name': 'JustBeMentalist', 'location': 'Shropshire', 'description': 'irreverent Mentalist: Behavioral Data hActivist, investigative writer monitoring data-driven political & social PsyOPs #dataprivacy protect Animal/Human Rights', 'url': 'https://t.co/yabJ8OlEQw', 'entities': {'url': {'urls': [{'url': 'https://t.co/yabJ8OlEQw', 'expanded_url': 'http://sleeplessdystopian.com', 'display_url': 'sleeplessdystopian.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 3153, 'friends_count': 1125, 'listed_count': 123, 'created_at': 'Mon Jan 26 15:43:29 +0000 2009', 'favourites_count': 377, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 191101, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '1A1B1F', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/687359419282239488/-12hV0wh_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/687359419282239488/-12hV0wh_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/19539923/1433070750', 'profile_link_color': '2FC2EF', 'profile_sidebar_border_color': '181A1E', 'profile_sidebar_fill_color': '252429', 'profile_text_color': '666666', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': True, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Mon Feb 17 06:34:09 +0000 2020', 'id': 1229292933301424128, 'id_str': '1229292933301424128', 'text': 'besook guyss besookk\nGa sabarrr akuuu 😭😭😭😭 baru x ini nunggu cb idol greget, gemesss, deg2an 😭😭dahlah #Dystopia… https://t.co/O3NpXBEdj1', 'truncated': True, 'entities': {'hashtags': [{'text': 'Dystopia', 'indices': [102, 111]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/O3NpXBEdj1', 'expanded_url': 'https://twitter.com/i/web/status/1229292933301424128', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [113, 136]}]}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1211448914919882752, 'id_str': '1211448914919882752', 'name': 'Woopsiesss 💢', 'screen_name': 'unknownbyDream', 'location': '', 'description': 'BTS 🕴💜 DREAMCATCHER 🖤💃\nARMYInSomnia.        💋KookMin HARD👄', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 31, 'friends_count': 40, 'listed_count': 0, 'created_at': 'Mon Dec 30 00:48:33 +0000 2019', 'favourites_count': 7329, 'utc_offset': Non ...

# %%
for friend in tweepy.Cursor(api.friends).items():
    print(friend._json)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# <ipython-input-17-3ea4c8bdbac8> in <module>()
# ----> 1 for friend in tweepy.Cursor(api.friends).items():
#       2     print(friend._json)
#
# /usr/local/lib/python3.6/dist-packages/tweepy/cursor.py in __next__(self)
#      47
#      48     def __next__(self):
# ---> 49         return self.next()
#      50
#      51     def next(self):
#
# /usr/local/lib/python3.6/dist-packages/tweepy/cursor.py in next(self)
#     195         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     196             # Reached end of current page, get the next page...
# --> 197             self.current_page = self.page_iterator.next()
#     198             self.page_index = -1
#     199         self.page_index += 1
#
# /usr/local/lib/python3.6/dist-packages/tweepy/cursor.py in next(self)
#      73         data, cursors = self.method(cursor=self.next_cursor,
#      74                                     *self.args,
# ---> 75                                     **self.kargs)
#      76         self.prev_cursor, self.next_cursor = cursors
#      77         if len(data) == 0:
#
# /usr/local/lib/python3.6/dist-packages/tweepy/binder.py in _call(*args, **kwargs)
#     248             return method
#     249         else:
# --> 250             return method.execute()
#     251
#     252     # Set pagination mode
#
# /usr/local/lib/python3.6/dist-packages/tweepy/binder.py in execute(self)
#     230
#     231                 if is_rate_limit_error_message(error_msg):
# --> 232                     raise RateLimitError(error_msg, resp)
#     233                 else:
#     234                     raise TweepError(error_msg, resp, api_code=api_error_code)
#
# RateLimitError: [{'message': 'Rate limit exceeded', 'code': 88}]

# %%
import json
tweets = []

for tweet in tweepy.Cursor(api.user_timeline).items():
  tweets.append(tweet._json)

#print(tweets)
with open('data.json', 'w') as outfile:
    json.dump(tweets, outfile)

# %%
# live streaming connection open
from tweepy import Stream
from tweepy.streaming import StreamListener
 
class MyListener(StreamListener):
 
    def on_data(self, data):
        try:
            with open('python.json', 'a') as f:
                f.write(data)
                return True
        except BaseException as e:
            print("Error on_data: %s" % str(e))
        return True
 
    def on_error(self, status):
        print(status)
        return True
 
twitter_stream = Stream(auth, MyListener())
twitter_stream.filter(track=['#python'])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-1f38ea27aa1a> in <module>()
#      18
#      19 twitter_stream = Stream(auth, MyListener())
# ---> 20 twitter_stream.filter(track=['#python'])
#
# /usr/local/lib/python3.6/dist-packages/tweepy/streaming.py in filter(self, follow, track, async, locations, stall_warnings, languages, encoding, filter_level)
#     448         self.session.params = {'delimited': 'length'}
#     449         self.host = 'stream.twitter.com'
# --> 450         self._start(async)
#     451
#     452     def sitestream(self, follow, stall_warnings=False,
#
# /usr/local/lib/python3.6/dist-packages/tweepy/streaming.py in _start(self, async)
#     362             self._thread.start()
#     363         else:
# --> 364             self._run()
#     365
#     366     def on_closed(self, resp):
#
# /usr/local/lib/python3.6/dist-packages/tweepy/streaming.py in _run(self)
#     264                     self.snooze_time = self.snooze_time_step
#     265                     self.listener.on_connect()
# --> 266                     self._read_loop(resp)
#     267             except (Timeout, ssl.SSLError) as exc:
#     268                 # This is still necessary, as a SSLError can actually be
#
# /usr/local/lib/python3.6/dist-packages/tweepy/streaming.py in _read_loop(self, resp)
#     314             length = 0
#     315             while not resp.raw.closed:
# --> 316                 line = buf.read_line().strip()
#     317                 if not line:
#     318                     self.listener.keep_alive()  # keep-alive new lines are expected
#
# /usr/local/lib/python3.6/dist-packages/tweepy/streaming.py in read_line(self, sep)
#     179             else:
#     180                 start = len(self._buffer)
# --> 181             self._buffer += self._stream.read(self._chunk_size)
#     182         return six.b('')
#     183
#
# /usr/local/lib/python3.6/dist-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     442             else:
#     443                 cache_content = False
# --> 444                 data = self._fp.read(amt)
#     445                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#     446                     # Close the connection when no data is returned
#
# /usr/lib/python3.6/http/client.py in read(self, amt)
#     457             # Amount is given, implement using readinto
#     458             b = bytearray(amt)
# --> 459             n = self.readinto(b)
#     460             return memoryview(b)[:n].tobytes()
#     461         else:
#
# /usr/lib/python3.6/http/client.py in readinto(self, b)
#     491
#     492         if self.chunked:
# --> 493             return self._readinto_chunked(b)
#     494
#     495         if self.length is not None:
#
# /usr/lib/python3.6/http/client.py in _readinto_chunked(self, b)
#     586         try:
#     587             while True:
# --> 588                 chunk_left = self._get_chunk_left()
#     589                 if chunk_left is None:
#     590                     return total_bytes
#
# /usr/lib/python3.6/http/client.py in _get_chunk_left(self)
#     554                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     555             try:
# --> 556                 chunk_left = self._read_next_chunk_size()
#     557             except ValueError:
#     558                 raise IncompleteRead(b'')
#
# /usr/lib/python3.6/http/client.py in _read_next_chunk_size(self)
#     514     def _read_next_chunk_size(self):
#     515         # Read the next chunk size from the file
# --> 516         line = self.fp.readline(_MAXLINE + 1)
#     517         if len(line) > _MAXLINE:
#     518             raise LineTooLong("chunk size")
#
# /usr/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# /usr/lib/python3.6/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1010                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1011                   self.__class__)
# -> 1012             return self.read(nbytes, buffer)
#    1013         else:
#    1014             return socket.recv_into(self, buffer, nbytes, flags)
#
# /usr/lib/python3.6/ssl.py in read(self, len, buffer)
#     872             raise ValueError("Read on closed or unwrapped SSL socket.")
#     873         try:
# --> 874             return self._sslobj.read(len, buffer)
#     875         except SSLError as x:
#     876             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# /usr/lib/python3.6/ssl.py in read(self, len, buffer)
#     629         """
#     630         if buffer is not None:
# --> 631             v = self._sslobj.read(len, buffer)
#     632         else:
#     633             v = self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import json
 
with open('data.json', 'r') as f:
    line = f.readline() # read only the first tweet/line
    tweet = json.loads(line) # load it as Python dict
    print(json.dumps(tweet, indent=4)) # pretty-print
# Out:
# [
#     {
#         "created_at": "Sun Feb 16 02:44:46 +0000 2020",
#         "id": 1228872821197111296,
#         "id_str": "1228872821197111296",
#         "text": "Here at #mpower cyclathon by Aditya Birla world, can't fail to notice the similarities in their dance format to\u2026 https://t.co/aQYGrfU5qH",
#         "truncated": true,
#         "entities": {
#             "hashtags": [
#                 {
#                     "text": "mpower",
#                     "indices": [
#                         8,
#                         15
#                     ]
#                 }
#             ],
#             "symbols": [],
#             "user_mentions": [],
#             "urls": [
#                 {
#                     "url": "https://t.co/aQYGrfU5qH",
#                     "expanded_url": "https://twitter.com/i/web/status/1228872821197111296",
#                     "display_url": "twitter.com/i/web/status/1\u2026",
#                     "indices": [
#                         113,
#                         136
#                     ]
#                 }
#             ]
#         },
#         "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#             "id": 989860160616189952,
#             "id_str": "989860160616189952",
#             "name": "Nilesh Arnaiya",
#             "screen_name": "NileshArnaiya",
#             "location": "",
#             "description": "https://t.co/4HfDCeaGhd. Mentor at Udacity & Mentorcruise. Freelancer",
#             "url": null,
#             "entities": {
#                 "description": {
#                     "urls": [
#                         {
#                             "url": "https://t.co/4HfDCeaGhd",
#                             "expanded_url": "https://Buildawn.com",
#                             "display_url": "Buildawn.com",
#                             "indices": [
#                                 0,
#                                 23
#                             ]
#                         }
#                     ]
#                 }
#             },
#             "protected": false,
#             "followers_count": 71,
#             "friends_count": 433,
#             "listed_count": 0,
#             "created_at": "Fri Apr 27 13:33:47 +0000 2018",
#             "favourites_count": 371,
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": false,
#             "verified": false,
#             "statuses_count": 78,
#             "lang": null,
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "F5F8FA",
#             "profile_background_image_url": null,
#             "profile_background_image_url_https": null,
#             "profile_background_tile": false,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/1185867120904531969/dSen0J5t_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1185867120904531969/dSen0J5t_normal.jpg",
#             "profile_link_color": "1DA1F2",
#             "profile_sidebar_border_color": "C0DEED",
#             "profile_sidebar_fill_color": "DDEEF6",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "has_extended_profile": true,
#             "default_profile": true,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none"
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "is_quote_status": false,
#         "retweet_count": 0,
#         "favorite_count": 0,
#         "favorited": false,
#         "retweeted": false,
#         "lang": "en"
#     },
#     {
#         "created_at": "Wed Feb 12 09:06:13 +0000 2020",
#         "id": 1227519265705586689,
#         "id_str": "1227519265705586689",
#         "text": "@batenjeen In India, forget unpaid internships, some startups ask monthly payments from students for getting indust\u2026 https://t.co/4BPG4TpAzp",
#         "truncated": true,
#         "entities": {
#             "hashtags": [],
#             "symbols": [],
#             "user_mentions": [
#                 {
#                     "screen_name": "batenjeen",
#                     "name": "radioactive khabibi",
#                     "id": 130773658,
#                     "id_str": "130773658",
#                     "indices": [
#                         0,
#                         10
#                     ]
#                 }
#             ],
#             "urls": [
#                 {
#                     "url": "https://t.co/4BPG4TpAzp",
#                     "expanded_url": "https://twitter.com/i/web/status/1227519265705586689",
#                     "display_url": "twitter.com/i/web/status/1\u2026",
#                     "indices": [
#                         117,
#                         140
#                     ]
#                 }
#             ]
#         },
#         "source": "<a href=\"https://mobile.twitter.com\" rel=\"nofollow\">Twitter Web App</a>",
#         "in_reply_to_status_id": 1225913673333583877,
#         "in_reply_to_status_id_str": "1225913673333583877",
#         "in_reply_to_user_id": 130773658,
#         "in_reply_to_user_id_str": "130773658",
#         "in_reply_to_screen_name": "batenjeen",
#         "user": {
#             "id": 989860160616189952,
#             "id_str": "989860160616189952",
#             "name": "Nilesh Arnaiya",
#             "screen_name": "NileshArnaiya",
#             "location": "",
#             "description": "https://t.co/4HfDCeaGhd. Mentor at Udacity & Mentorcruise. Freelancer",
#             "url": null,
#             "entities": {
#                 "description": {
#                     "urls": [
#                         {
#                             "url": "https://t.co/4HfDCeaGhd",
#                             "expanded_url": "https://Buildawn.com",
#                             "display_url": "Buildawn.com",
#                             "indices": [
#                                 0,
#                                 23
#                             ]
#                         }
#                     ]
#                 }
#             },
#             "protected": false,
#             "followers_count": 71,
#             "friends_count": 433,
#             "listed_count": 0,
#             "created_at": "Fri Apr 27 13:33:47 +0000 2018",
#             "favourites_count": 371,
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": false,
#             "verified": false,
#             "statuses_count": 78,
#             "lang": null,
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "F5F8FA",
#             "profile_background_image_url": null,
#             "profile_background_image_url_https": null,
#             "profile_background_tile": false,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/1185867120904531969/dSen0J5t_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1185867120904531969/dSen0J5t_normal.jpg",
#             "profile_link_color": "1DA1F2",
#             "profile_sidebar_border_color": "C0DEED",
#             "profile_sidebar_fill_color": "DDEEF6",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "has_extended_profile": true,
#             "default_profile": true,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none"
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "is_quote_status": false,
#         "retweet_count": 0,
#         "favorite_count": 0,
#         "favorited": false,
#         "retweeted": false,
#         "lang": "en"
#     },
#     {
#         "created_at": "Mon Feb 03 06:21:51 +0000 2020",
#         "id": 1224216407639879680,
#         "id_str": "1224216407639879680",
#         "text": "Food arrived in 10 mins with superfood of the day #eatfit @BeCureFit \ud83d\ude0b https://t.co/bsTMKNiW3a",
#         "truncated": false,
#         "entities": {
#             "hashtags": [
#                 {
#                     "text": "eatfit",
#                     "indices": [
#                         50,
#                         57
#                     ]
#                 }
#             ],
#             "symbols": [],
#             "user_mentions": [
#                 {
#                     "screen_name": "BeCureFit",
#                     "name": "cure.fit",
#                     "id": 3187963356,
#                     "id_str": "3187963356",
#                     "indices": [
#                         58,
#                         68
#                     ]
#                 }
#             ],
#             "urls": [],
#             "media": [
#                 {
#                     "id": 1224216396797636609,
#                     "id_str": "1224216396797636609",
#                     "indices": [
#                         71,
#                         94
#                     ],
#                     "media_url": "http://pbs.twimg.com/media/EP1KU6NU8AEfyvM.jpg",
#                     "media_url_https": "https://pbs.twimg.com/media/EP1KU6NU8AEfyvM.jpg",
#                     "url": "https://t.co/bsTMKNiW3a",
#                     "display_url": "pic.twitter.com/bsTMKNiW3a",
#                     "expanded_url": "https://twitter.com/NileshArnaiya/status/1224216407639879680/photo/1",
#                     "type": "photo",
#                     "sizes": {
#                         "medium": {
#                             "w": 1200,
#                             "h": 675,
#                             "resize": "fit"
#                         },
#                         "thumb": {
#                             "w": 150,
#                             "h": 150,
#                             "resize": "crop"
#                         },
#                         "small": {
#                             "w": 680,
#                             "h": 383,
#                             "resize": "fit"
#                         },
#                         "large": {
#                             "w": 2048,
#                             "h": 1152,
#                             "resize": "fit"
#                         }
#                     }
#                 }
#             ]
#         },
#         "extended_entities": {
#             "media": [
#                 {
#                     "id": 1224216396797636609,
#                     "id_str": "1224216396797636609",
#                     "indices": [
#                         71,
#                         94
#                     ],
#                     "media_url": "http://pbs.twimg.com/media/EP1KU6NU8AEfyvM.jpg",
#                     "media_url_https": "https://pbs.twimg.com/media/EP1KU6NU8AEfyvM.jpg",
#                     "url": "https://t.co/bsTMKNiW3a",
#                     "display_url": "pic.twitter.com/bsTMKNiW3a",
#                     "expanded_url": "https://twitter.com/NileshArnaiya/status/1224216407639879680/photo/1",
#                     "type": "photo",
#                     "sizes": {
#                         "medium": {
#                             "w": 1200,
#                             "h": 675,
#                             "resize": "fit"
#                         },
#                         "thumb": {
#                             "w": 150,
#                             "h": 150,
#                             "resize": "crop"
#                         },
#                         "small": {
#                             "w": 680,
#                             "h": 383,
#                             "resize": "fit"
#                         },
#                         "large": {
#                             "w": 2048,
#                             "h": 1152,
#                             "resize": "fit"
#                         }
#                     }
#                 }
#             ]
#         },
#         "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#             "id": 989860160616189952,
#             "id_str": "989860160616189952",
#             "name": "Nilesh Arnaiya",
#             "screen_name": "NileshArnaiya",
#             "location": "",
#             "description": "https://t.co/4HfDCeaGhd. Mentor at Udacity & Mentorcruise. Freelancer",
#             "url": null,
#             "entities": {
#                 "description": {
#                     "urls": [
#                         {
#                             "url": "https://t.co/4HfDCeaGhd",
#                             "expanded_url": "https://Buildawn.com",
#                             "display_url": "Buildawn.com",
#                             "indices": [
#                                 0,
#                                 23
#                             ]
#                         }
#                     ]
#                 }
#             },
#             "protected": false,
#             "followers_count": 71,
#             "friends_count": 433,
#             "listed_count": 0,
#             "created_at": "Fri Apr 27 13:33:47 +0000 2018",
#             "favourites_count": 371,
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": false,
#             "verified": false,
#             "statuses_count": 78,
#             "lang": null,
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "F5F8FA",
#             "profile_background_image_url": null,
#             "profile_background_image_url_https": null,
#             "profile_background_tile": false,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/1185867120904531969/dSen0J5t_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1185867120904531969/dSen0J5t_normal.jpg",
#             "profile_link_color": "1DA1F2",
#             "profile_sidebar_border_color": "C0DEED",
#             "profile_sidebar_fill_color": "DDEEF6",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "has_extended_profile": true,
#             "default_profile": true,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none"
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "is_quote_status": false,
#         "retweet_count": 0,
#         "favorite_count": 1,
#         "favorited": false,
#         "retweeted": false,
#         "possibly_sensitive": false,
#         "lang": "en"
#     },
#     {
#         "created_at": "Fri Jan 31 11:36:12 +0000 2020",
#         "id": 1223208354249506816,
#         "id_str": "1223208354249506816",
#         "text": "Thank you @codeartistryio for writing this helpful article.\n\nThe React Cheatsheet for 2020 (+ real-world examples)\n\nhttps://t.co/colM3HyMmB",
#         "truncated": false,
#         "entities": {
#             "hashtags": [],
#             "symbols": [],
#             "user_mentions": [
#                 {
#                     "screen_name": "codeartistryio",
#                     "name": "Code Artistry",
#                     "id": 1124541599814434817,
#                     "id_str": "1124541599814434817",
#                     "indices": [
#                         10,
#                         25
#                     ]
#                 }
#             ],
#             "urls": [
#                 {
#                     "url": "https://t.co/colM3HyMmB",
#                     "expanded_url": "https://www.freecodecamp.org/news/the-react-cheatsheet-for-2020/",
#                     "display_url": "freecodecamp.org/news/the-react\u2026",
#                     "indices": [
#                         116,
#                         139
#                     ]
#                 }
#             ]
#         },
#         "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#             "id": 989860160616189952,
#             "id_str": "989860160616189952",
#             "name": "Nilesh Arnaiya",
#             "screen_name": "NileshArnaiya",
#             "location": "",
#             "description": "https://t.co/4HfDCeaGhd. Mentor at Udacity & Mentorcruise. Freelancer",
#             "url": null,
#             "entities": {
#                 "description": {
#                     "urls": [
#                         {
#                             "url": "https://t.co/4HfDCeaGhd",
#                             "expanded_url": "https://Buildawn.com",
#                             "display_url": "Buildawn.com",
#                             "indices": [
#                                 0,
#                                 23
#                             ]
#                         }
#                     ]
#                 }
#             },
#             "protected": false,
#             "followers_count": 71,
#             "friends_count": 433,
#             "listed_count": 0,
#             "created_at": "Fri Apr 27 13:33:47 +0000 2018",
#             "favourites_count": 371,
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": false,
#             "verified": false,
#             "statuses_count": 78,
#             "lang": null,
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "F5F8FA",
#             "profile_background_image_url": null,
#             "profile_background_image_url_https": null,
#             "profile_background_tile": false,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/1185867120904531969/dSen0J5t_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1185867120904531969/dSen0J5t_normal.jpg",
#             "profile_link_color": "1DA1F2",
#             "profile_sidebar_border_color": "C0DEED",
#             "profile_sidebar_fill_color": "DDEEF6",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "has_extended_profile": true,
#             "default_profile": true,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none"
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "is_quote_status": false,
#         "retweet_count": 0,
#         "favorite_count": 1,
#         "favorited": false,
#         "retweeted": false,
#         "possibly_sensitive": false,
#         "lang": "en"
#     },
#     {
#         "created_at": "Tue Jan 28 16:21:52 +0000 2020",
#         "id": 1222193082499682309,
#         "id_str": "1222193082499682309",
#         "text": "@BeCureFit is a revolution in fitness with top quality instructors, various workout formats, pushing the limits eve\u2026 https://t.co/9t7WGSvUIn",
#         "truncated": true,
#         "entities": {
#             "hashtags": [],
#             "symbols": [],
#             "user_mentions": [
#                 {
#                     "screen_name": "BeCureFit",
#                     "name": "cure.fit",
#                     "id": 3187963356,
#                     "id_str": "3187963356",
#                     "indices": [
#                         0,
#                         10
#                     ]
#                 }
#             ],
#             "urls": [
#                 {
#                     "url": "https://t.co/9t7WGSvUIn",
#                     "expanded_url": "https://twitter.com/i/web/status/1222193082499682309",
#                     "display_url": "twitter.com/i/web/status/1\u2026",
#                     "indices": [
#                         117,
#                         140
#                     ]
#                 }
#             ]
#         },
#         "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": 3187963356,
#         "in_reply_to_user_id_str": "3187963356",
#         "in_reply_to_screen_name": "BeCureFit",
#         "user": {
#             "id": 989860160616189952,
#             "id_str": "989860160616189952",
#             "name": "Nilesh Arnaiya",
#             "screen_name": "NileshArnaiya",
#             "location": "",
#             "description": "https://t.co/4HfDCeaGhd. Mentor at Udacity & Mentorcruise. Freelancer",
#             "url": null,
#             "entities": {
#                 "description": {
#                     "urls": [
#                         {
#                             "url": "https://t.co/4HfDCeaGhd",
#                             "expanded_url": "https://Buildawn.com",
#                             "display_url": "Buildawn.com",
#                             "indices": [
#                                 0,
#                                 23
#                             ]
#                         }
#                     ]
#                 }
#             },
#             "protected": false,
#             "followers_count": 71,
#             "friends_count": 433,
#             "listed_count": 0,
#             "created_at": "Fri Apr 27 13:33:47 +0000 2018",
#             "favourites_count": 371,
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": false,
#             "verified": false,
#             "statuses_count": 78,
#             "lang": null,
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "F5F8FA",
#             "profile_background_image_url": null,
#             "profile_background_image_url_https": null,
#             "profile_background_tile": false,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/1185867120904531969/dSen0J5t_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1185867120904531969/dSen0J5t_normal.jpg",
#             "profile_link_color": "1DA1F2",
#             "profile_sidebar_border_color": "C0DEED",
#             "profile_sidebar_fill_color": "DDEEF6",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "has_extended_profile": true,
#             "default_profile": true,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none"
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "is_quote_status": false,
#         "retweet_count": 0,
#         "favorite_count": 1,
#         "favorited": false,
#         "retweeted": false,
#         "lang": "en"
#     },
#     {
#         "created_at": "Tue Jan 28 10:25:39 +0000 2020",
#         "id": 1222103435647934464,
#         "id_str": "1222103435647934464",
#         "text": "Learn Applied AI, Data Science, ML, Web &amp; App Development along with core computer science knowledge meant for ever\u2026 https://t.co/9j7oltpdwv",
#         "truncated": true,
#         "entities": {
#             "hashtags": [],
#             "symbols": [],
#             "user_mentions": [],
#             "urls": [
#                 {
#                     "url": "https://t.co/9j7oltpdwv",
#                     "expanded_url": "https://twitter.com/i/web/status/1222103435647934464",
#                     "display_url": "twitter.com/i/web/status/1\u2026",
#                     "indices": [
#                         121,
#                         144
#                     ]
#                 }
#             ]
#         },
#         "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#             "id": 989860160616189952,
#             "id_str": "989860160616189952",
#             "name": "Nilesh Arnaiya",
#             "screen_name": "NileshArnaiya",
#             "location": "",
#             "description": "https://t.co/4HfDCeaGhd. Mentor at Udacity & Mentorcruise. Freelancer",
#             "url": null,
#             "entities": {
#                 "description": {
#                     "urls": [
#                         {
#                             "url": "https://t.co/4HfDCeaGhd",
#                             "expanded_url": "https://Buildawn.com",
#                             "display_url": "Buildawn.com",
#                             "indices": [
#                                 0,
#                                 23
#                             ]
#                         }
#                     ]
#                 }
#             },
#             "protected": false,
#             "followers_count": 71,
#             "friends_count": 433,
#             "listed_count": 0,
#             "created_at": "Fri Apr 27 13:33:47 +0000 2018",
#             "favourites_count": 371,
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": false,
#             "verified": false,
#             "statuses_count": 78,
#             "lang": null,
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "F5F8FA",
#             "profile_background_image_url": null,
#             "profile_background_image_url_https": null,
#             "profile_background_tile": false,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/1185867120904531969/dSen0J5t_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1185867120904531969/dSen0J5t_normal.jpg",
#             "profile_link_color": "1DA1F2",
#             "profile_sidebar_border_color": "C0DEED",
#             "profile_sidebar_fill_color": "DDEEF6",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "has_extended_profile": true,
#             "default_profile": true,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none"
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "is_quote_status": false,
#         "retweet_count": 0,
#         "favorite_count": 0,
#         "favorited": false,
#         "retweeted": false,
#         "possibly_sensitive": false,
#         "lang": "en"
#     },
#     {
#         "created_at": "Tue Jan 28 10:13:13 +0000 2020",
#         "id": 1222100307796086784,
#         "id_str": "1222100307796086784",
#         "text": "Compilation of YouTube resources in one app. University and mooc content \nMust download - Learn Applied AI, Data Sc\u2026 https://t.co/9c3EHp9Cxw",
#         "truncated": true,
#         "entities": {
#             "hashtags": [],
#             "symbols": [],
#             "user_mentions": [],
#             "urls": [
#                 {
#                     "url": "https://t.co/9c3EHp9Cxw",
#                     "expanded_url": "https://twitter.com/i/web/status/1222100307796086784",
#                     "display_url": "twitter.com/i/web/status/1\u2026",
#                     "indices": [
#                         117,
#                         140
#                     ]
#                 }
#             ]
#         },
#         "source": "<a href=\"http://instagram.com\" rel=\"nofollow\">Instagram</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#             "id": 989860160616189952,
#             "id_str": "989860160616189952",
#             "name": "Nilesh Arnaiya",
#             "screen_name": "NileshArnaiya",
#             "location": "",
#             "description": "https://t.co/4HfDCeaGhd. Mentor at Udacity & Mentorcruise. Freelancer",
#             "url": null,
#             "entities": {
#                 "description": {
#                     "urls": [
#                         {
#                             "url": "https://t.co/4HfDCeaGhd",
#                             "expanded_url": "https://Buildawn.com",
#                             "display_url": "Buildawn.com",
#                             "indices": [
#                                 0,
#                                 23
#                             ]
#                         }
#                     ]
#                 }
#             },
#             "protected": false,
#             "followers_count": 71,
#             "friends_count": 433,
#             "listed_count": 0,
#             "created_at": "Fri Apr 27 13:33:47 +0000 2018",
#             "favourites_count": 371,
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": false,
#             "verified": false,
#             "statuses_count": 78,
#             "lang": null,
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "F5F8FA",
#             "profile_background_image_url": null,
#             "profile_background_image_url_https": null,
#             "profile_background_tile": false,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/1185867120904531969/dSen0J5t_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1185867120904531969/dSen0J5t_normal.jpg",
#             "profile_link_color": "1DA1F2",
#             "profile_sidebar_border_color": "C0DEED",
#             "profile_sidebar_fill_color": "DDEEF6",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "has_extended_profile": true,
#             "default_profile": true,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none"
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "is_quote_status": false,
#         "retweet_count": 1,
#         "favorite_count": 0,
#         "favorited": false,
#         "retweeted": false,
#         "possibly_sensitive": false,
#         "lang": "en"
#     },
#     {
#         "created_at": "Thu Jan 23 10:26:52 +0000 2020",
#         "id": 1220291802483134464,
#         "id_str": "1220291802483134464",
#         "text": "RT @mathwis_emily: If you know then you know. If you don't know then it's time to get to know. Placeholder 2020 \ud83d\ude01\u2665\ufe0f @DeepIndaba. https://t.\u2026",
#         "truncated": false,
#         "entities": {
#             "hashtags": [],
#             "symbols": [],
#             "user_mentions": [
#                 {
#                     "screen_name": "mathwis_emily",
#                     "name": "Emily Muller",
#                     "id": 847142598213095425,
#                     "id_str": "847142598213095425",
#                     "indices": [
#                         3,
#                         17
#                     ]
#                 },
#                 {
#                     "screen_name": "DeepIndaba",
#                     "name": "Deep Learning Indaba",
#                     "id": 848799224854609920,
#                     "id_str": "848799224854609920",
#                     "indices": [
#                         116,
#                         127
#                     ]
#                 }
#             ],
#             "urls": []
#         },
#         "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#             "id": 989860160616189952,
#             "id_str": "989860160616189952",
#             "name": "Nilesh Arnaiya",
#             "screen_name": "NileshArnaiya",
#             "location": "",
#             "description": "https://t.co/4HfDCeaGhd. Mentor at Udacity & Mentorcruise. Freelancer",
#             "url": null,
#             "entities": {
#                 "description": {
#                     "urls": [
#                         {
#                             "url": "https://t.co/4HfDCeaGhd",
#                             "expanded_url": "https://Buildawn.com",
#                             "display_url": "Buildawn.com",
#                             "indices": [
#                                 0,
#                                 23
#                             ]
#                         }
#                     ]
#                 }
#             },
#             "protected": false,
#             "followers_count": 71,
#             "friends_count": 433,
#             "listed_count": 0,
#             "created_at": "Fri Apr 27 13:33:47 +0000 2018",
#             "favourites_count": 371,
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": false,
#             "verified": false,
#             "statuses_count": 78,
#             "lang": null,
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "F5F8FA",
#             "profile_background_image_url": null,
#             "profile_background_image_url_https": null,
#             "profile_background_tile": false,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/1185867120904531969/dSen0J5t_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1185867120904531969/dSen0J5t_normal.jpg",
#             "profile_link_color": "1DA1F2",
#             "profile_sidebar_border_color": "C0DEED",
#             "profile_sidebar_fill_color": "DDEEF6",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "has_extended_profile": true,
#             "default_profile": true,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none"
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "retweeted_status": {
#             "created_at": "Wed Jan 22 17:16:06 +0000 2020",
#             "id": 1220032401650438145,
#             "id_str": "1220032401650438145",
#             "text": "If you know then you know. If you don't know then it's time to get to know. Placeholder 2020 \ud83d\ude01\u2665\ufe0f @DeepIndaba. https://t.co/iS7W6gPCZv",
#             "truncated": false,
#             "entities": {
#                 "hashtags": [],
#                 "symbols": [],
#                 "user_mentions": [
#                     {
#                         "screen_name": "DeepIndaba",
#                         "name": "Deep Learning Indaba",
#                         "id": 848799224854609920,
#                         "id_str": "848799224854609920",
#                         "indices": [
#                             97,
#                             108
#                         ]
#                     }
#                 ],
#                 "urls": [],
#                 "media": [
#                     {
#                         "id": 1220032389159817216,
#                         "id_str": "1220032389159817216",
#                         "indices": [
#                             110,
#                             133
#                         ],
#                         "media_url": "http://pbs.twimg.com/media/EO5s_nJXkAAQ-K2.jpg",
#                         "media_url_https": "https://pbs.twimg.com/media/EO5s_nJXkAAQ-K2.jpg",
#                         "url": "https://t.co/iS7W6gPCZv",
#                         "display_url": "pic.twitter.com/iS7W6gPCZv",
#                         "expanded_url": "https://twitter.com/mathwis_emily/status/1220032401650438145/photo/1",
#                         "type": "photo",
#                         "sizes": {
#                             "thumb": {
#                                 "w": 150,
#                                 "h": 150,
#                                 "resize": "crop"
#                             },
#                             "medium": {
#                                 "w": 1080,
#                                 "h": 911,
#                                 "resize": "fit"
#                             },
#                             "large": {
#                                 "w": 1080,
#                                 "h": 911,
#                                 "resize": "fit"
#                             },
#                             "small": {
#                                 "w": 680,
#                                 "h": 574,
#                                 "resize": "fit"
#                             }
#                         }
#                     }
#                 ]
#             },
#             "extended_entities": {
#                 "media": [
#                     {
#                         "id": 1220032389159817216,
#                         "id_str": "1220032389159817216",
#                         "indices": [
#                             110,
#                             133
#                         ],
#                         "media_url": "http://pbs.twimg.com/media/EO5s_nJXkAAQ-K2.jpg",
#                         "media_url_https": "https://pbs.twimg.com/media/EO5s_nJXkAAQ-K2.jpg",
#                         "url": "https://t.co/iS7W6gPCZv",
#                         "display_url": "pic.twitter.com/iS7W6gPCZv",
#                         "expanded_url": "https://twitter.com/mathwis_emily/status/1220032401650438145/photo/1",
#                         "type": "photo",
#                         "sizes": {
#                             "thumb": {
#                                 "w": 150,
#                                 "h": 150,
#                                 "resize": "crop"
#                             },
#                             "medium": {
#                                 "w": 1080,
#                                 "h": 911,
#                                 "resize": "fit"
#                             },
#                             "large": {
#                                 "w": 1080,
#                                 "h": 911,
#                                 "resize": "fit"
#                             },
#                             "small": {
#                                 "w": 680,
#                                 "h": 574,
#                                 "resize": "fit"
#                             }
#                         }
#                     }
#                 ]
#             },
#             "source": "<a href=\"https://mobile.twitter.com\" rel=\"nofollow\">Twitter Web App</a>",
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "in_reply_to_screen_name": null,
#             "user": {
#                 "id": 847142598213095425,
#                 "id_str": "847142598213095425",
#                 "name": "Emily Muller",
#                 "screen_name": "mathwis_emily",
#                 "location": "",
#                 "description": "UK, SA. part time mathematician and vegetarian. full time data fiend. @Pathways2Equity. @AIMSacza alumni.",
#                 "url": null,
#                 "entities": {
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "protected": false,
#                 "followers_count": 317,
#                 "friends_count": 347,
#                 "listed_count": 5,
#                 "created_at": "Wed Mar 29 17:45:09 +0000 2017",
#                 "favourites_count": 1649,
#                 "utc_offset": null,
#                 "time_zone": null,
#                 "geo_enabled": true,
#                 "verified": false,
#                 "statuses_count": 412,
#                 "lang": null,
#                 "contributors_enabled": false,
#                 "is_translator": false,
#                 "is_translation_enabled": false,
#                 "profile_background_color": "F5F8FA",
#                 "profile_background_image_url": null,
#                 "profile_background_image_url_https": null,
#                 "profile_background_tile": false,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/849361832653488130/mOp6oiD1_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/849361832653488130/mOp6oiD1_normal.jpg",
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/847142598213095425/1491338689",
#                 "profile_link_color": "1DA1F2",
#                 "profile_sidebar_border_color": "C0DEED",
#                 "profile_sidebar_fill_color": "DDEEF6",
#                 "profile_text_color": "333333",
#                 "profile_use_background_image": true,
#                 "has_extended_profile": true,
#                 "default_profile": true,
#                 "default_profile_image": false,
#                 "following": false,
#                 "follow_request_sent": false,
#                 "notifications": false,
#                 "translator_type": "none"
#             },
#             "geo": null,
#             "coordinates": null,
#             "place": null,
#             "contributors": null,
#             "is_quote_status": false,
#             "retweet_count": 15,
#             "favorite_count": 47,
#             "favorited": true,
#             "retweeted": true,
#             "possibly_sensitive": false,
#             "lang": "en"
#         },
#         "is_quote_status": false,
#         "retweet_count": 15,
#         "favorite_count": 0,
#         "favorited": true,
#         "retweeted": true,
#         "lang": "en"
#     },
#     {
#         "created_at": "Thu Jan 23 09:22:12 +0000 2020",
#         "id": 1220275530530017280,
#         "id_str": "1220275530530017280",
#         "text": "Who needs these? Tag your friends.\n\n#pcgaming #gamingsetups\n#buildawn #deeplearning #artificialintelligence\u2026 https://t.co/AYy77aCNSu",
#         "truncated": true,
#         "entities": {
#             "hashtags": [
#                 {
#                     "text": "pcgaming",
#                     "indices": [
#                         36,
#                         45
#                     ]
#                 },
#                 {
#                     "text": "gamingsetups",
#                     "indices": [
#                         46,
#                         59
#                     ]
#                 },
#                 {
#                     "text": "buildawn",
#                     "indices": [
#                         60,
#                         69
#                     ]
#                 },
#                 {
#                     "text": "deeplearning",
#                     "indices": [
#                         70,
#                         83
#                     ]
#                 },
#                 {
#                     "text": "artificialintelligence",
#                     "indices": [
#                         84,
#                         107
#                     ]
#                 }
#             ],
#             "symbols": [],
#             "user_mentions": [],
#             "urls": [
#                 {
#                     "url": "https://t.co/AYy77aCNSu",
#                     "expanded_url": "https://twitter.com/i/web/status/1220275530530017280",
#                     "display_url": "twitter.com/i/web/status/1\u2026",
#                     "indices": [
#                         109,
#                         132
#                     ]
#                 }
#             ]
#         },
#         "source": "<a href=\"http://instagram.com\" rel=\"nofollow\">Instagram</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#             "id": 989860160616189952,
#             "id_str": "989860160616189952",
#             "name": "Nilesh Arnaiya",
#             "screen_name": "NileshArnaiya",
#             "location": "",
#             "description": "https://t.co/4HfDCeaGhd. Mentor at Udacity & Mentorcruise. Freelancer",
#             "url": null,
#             "entities": {
#                 "description": {
#                     "urls": [
#                         {
#                             "url": "https://t.co/4HfDCeaGhd",
#                             "expanded_url": "https://Buildawn.com",
#                             "display_url": "Buildawn.com",
#                             "indices": [
#                                 0,
#                                 23
#                             ]
#                         }
#                     ]
#                 }
#             },
#             "protected": false,
#             "followers_count": 71,
#             "friends_count": 433,
#             "listed_count": 0,
#             "created_at": "Fri Apr 27 13:33:47 +0000 2018",
#             "favourites_count": 371,
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": false,
#             "verified": false,
#             "statuses_count": 78,
#             "lang": null,
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "F5F8FA",
#             "profile_background_image_url": null,
#             "profile_background_image_url_https": null,
#             "profile_background_tile": false,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/1185867120904531969/dSen0J5t_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1185867120904531969/dSen0J5t_normal.jpg",
#             "profile_link_color": "1DA1F2",
#             "profile_sidebar_border_color": "C0DEED",
#             "profile_sidebar_fill_color": "DDEEF6",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "has_extended_profile": true,
#             "default_profile": true,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none"
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "is_quote_status": false,
#         "retweet_count": 0,
#         "favorite_count": 1,
#         "favorited": false,
#         "retweeted": false,
#         "possibly_sensitive": false,
#         "lang": "en"
#     },
#     {
#         "created_at": "Thu Jan 23 08:52:39 +0000 2020",
#         "id": 1220268093089423363,
#         "id_str": "1220268093089423363",
#         "text": "Detect DeepFakes images and videos with the Nvidia Titan XP and MacBook Pro with Thunderbolt2 now on\u2026 https://t.co/LjxuMC0xWA",
#         "truncated": true,
#         "entities": {
#             "hashtags": [],
#             "symbols": [],
#             "user_mentions": [],
#             "urls": [
#                 {
#                     "url": "https://t.co/LjxuMC0xWA",
# ...
#         "truncated": false,
#         "entities": {
#             "hashtags": [
#                 {
#                     "text": "hackathon",
#                     "indices": [
#                         93,
#                         103
#                     ]
#                 },
#                 {
#                     "text": "devfolio",
#                     "indices": [
#                         104,
#                         113
#                     ]
#                 }
#             ],
#             "symbols": [],
#             "user_mentions": [
#                 {
#                     "screen_name": "Devfolioco",
#                     "name": "Devfolio",
#                     "id": 995630701994098689,
#                     "id_str": "995630701994098689",
#                     "indices": [
#                         57,
#                         68
#                     ]
#                 }
#             ],
#             "urls": [
#                 {
#                     "url": "https://t.co/pwymtNzVpn",
#                     "expanded_url": "https://devfolio.co/signup?ref=8e88fe1c9d",
#                     "display_url": "devfolio.co/signup?ref=8e8\u2026",
#                     "indices": [
#                         69,
#                         92
#                     ]
#                 }
#             ]
#         },
#         "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#             "id": 989860160616189952,
#             "id_str": "989860160616189952",
#             "name": "Nilesh Arnaiya",
#             "screen_name": "NileshArnaiya",
#             "location": "",
#             "description": "https://t.co/4HfDCeaGhd. Mentor at Udacity & Mentorcruise. Freelancer",
#             "url": null,
#             "entities": {
#                 "description": {
#                     "urls": [
#                         {
#                             "url": "https://t.co/4HfDCeaGhd",
#                             "expanded_url": "https://Buildawn.com",
#                             "display_url": "Buildawn.com",
#                             "indices": [
#                                 0,
#                                 23
#                             ]
#                         }
#                     ]
#                 }
#             },
#             "protected": false,
#             "followers_count": 71,
#             "friends_count": 433,
#             "listed_count": 0,
#             "created_at": "Fri Apr 27 13:33:47 +0000 2018",
#             "favourites_count": 371,
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": false,
#             "verified": false,
#             "statuses_count": 78,
#             "lang": null,
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "F5F8FA",
#             "profile_background_image_url": null,
#             "profile_background_image_url_https": null,
#             "profile_background_tile": false,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/1185867120904531969/dSen0J5t_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1185867120904531969/dSen0J5t_normal.jpg",
#             "profile_link_color": "1DA1F2",
#             "profile_sidebar_border_color": "C0DEED",
#             "profile_sidebar_fill_color": "DDEEF6",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "has_extended_profile": true,
#             "default_profile": true,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none"
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "is_quote_status": false,
#         "retweet_count": 2,
#         "favorite_count": 6,
#         "favorited": false,
#         "retweeted": false,
#         "possibly_sensitive": false,
#         "lang": "en"
#     },
#     {
#         "created_at": "Mon Dec 10 04:10:57 +0000 2018",
#         "id": 1071980564004122625,
#         "id_str": "1071980564004122625",
#         "text": "I finished 42's online tests! What about you, do you think you are #42born2codeUS? https://t.co/suKMgoPzuZ",
#         "truncated": false,
#         "entities": {
#             "hashtags": [
#                 {
#                     "text": "42born2codeUS",
#                     "indices": [
#                         67,
#                         81
#                     ]
#                 }
#             ],
#             "symbols": [],
#             "user_mentions": [],
#             "urls": [
#                 {
#                     "url": "https://t.co/suKMgoPzuZ",
#                     "expanded_url": "https://42.us.org",
#                     "display_url": "42.us.org",
#                     "indices": [
#                         83,
#                         106
#                     ]
#                 }
#             ]
#         },
#         "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#             "id": 989860160616189952,
#             "id_str": "989860160616189952",
#             "name": "Nilesh Arnaiya",
#             "screen_name": "NileshArnaiya",
#             "location": "",
#             "description": "https://t.co/4HfDCeaGhd. Mentor at Udacity & Mentorcruise. Freelancer",
#             "url": null,
#             "entities": {
#                 "description": {
#                     "urls": [
#                         {
#                             "url": "https://t.co/4HfDCeaGhd",
#                             "expanded_url": "https://Buildawn.com",
#                             "display_url": "Buildawn.com",
#                             "indices": [
#                                 0,
#                                 23
#                             ]
#                         }
#                     ]
#                 }
#             },
#             "protected": false,
#             "followers_count": 71,
#             "friends_count": 433,
#             "listed_count": 0,
#             "created_at": "Fri Apr 27 13:33:47 +0000 2018",
#             "favourites_count": 371,
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": false,
#             "verified": false,
#             "statuses_count": 78,
#             "lang": null,
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "F5F8FA",
#             "profile_background_image_url": null,
#             "profile_background_image_url_https": null,
#             "profile_background_tile": false,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/1185867120904531969/dSen0J5t_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1185867120904531969/dSen0J5t_normal.jpg",
#             "profile_link_color": "1DA1F2",
#             "profile_sidebar_border_color": "C0DEED",
#             "profile_sidebar_fill_color": "DDEEF6",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "has_extended_profile": true,
#             "default_profile": true,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none"
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "is_quote_status": false,
#         "retweet_count": 0,
#         "favorite_count": 0,
#         "favorited": false,
#         "retweeted": false,
#         "possibly_sensitive": false,
#         "lang": "en"
#     },
#     {
#         "created_at": "Mon Oct 01 15:51:55 +0000 2018",
#         "id": 1046789817877614594,
#         "id_str": "1046789817877614594",
#         "text": "Wrote a blog explaining the sieve of eratosthenes algorithm https://t.co/HmirnDPamj",
#         "truncated": false,
#         "entities": {
#             "hashtags": [],
#             "symbols": [],
#             "user_mentions": [],
#             "urls": [
#                 {
#                     "url": "https://t.co/HmirnDPamj",
#                     "expanded_url": "https://iq.opengenus.org/the-sieve-of-eratosthenes/",
#                     "display_url": "iq.opengenus.org/the-sieve-of-e\u2026",
#                     "indices": [
#                         60,
#                         83
#                     ]
#                 }
#             ]
#         },
#         "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#             "id": 989860160616189952,
#             "id_str": "989860160616189952",
#             "name": "Nilesh Arnaiya",
#             "screen_name": "NileshArnaiya",
#             "location": "",
#             "description": "https://t.co/4HfDCeaGhd. Mentor at Udacity & Mentorcruise. Freelancer",
#             "url": null,
#             "entities": {
#                 "description": {
#                     "urls": [
#                         {
#                             "url": "https://t.co/4HfDCeaGhd",
#                             "expanded_url": "https://Buildawn.com",
#                             "display_url": "Buildawn.com",
#                             "indices": [
#                                 0,
#                                 23
#                             ]
#                         }
#                     ]
#                 }
#             },
#             "protected": false,
#             "followers_count": 71,
#             "friends_count": 433,
#             "listed_count": 0,
#             "created_at": "Fri Apr 27 13:33:47 +0000 2018",
#             "favourites_count": 371,
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": false,
#             "verified": false,
#             "statuses_count": 78,
#             "lang": null,
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "F5F8FA",
#             "profile_background_image_url": null,
#             "profile_background_image_url_https": null,
#             "profile_background_tile": false,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/1185867120904531969/dSen0J5t_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1185867120904531969/dSen0J5t_normal.jpg",
#             "profile_link_color": "1DA1F2",
#             "profile_sidebar_border_color": "C0DEED",
#             "profile_sidebar_fill_color": "DDEEF6",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "has_extended_profile": true,
#             "default_profile": true,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none"
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "is_quote_status": false,
#         "retweet_count": 0,
#         "favorite_count": 0,
#         "favorited": false,
#         "retweeted": false,
#         "possibly_sensitive": false,
#         "lang": "en"
#     },
#     {
#         "created_at": "Wed Sep 26 02:48:25 +0000 2018",
#         "id": 1044780702942875648,
#         "id_str": "1044780702942875648",
#         "text": "Starting today I'll be committing 100 algorithm implementations using python for the next 100 days #100daysofcode\u2026 https://t.co/Ctqnz8I8b8",
#         "truncated": true,
#         "entities": {
#             "hashtags": [
#                 {
#                     "text": "100daysofcode",
#                     "indices": [
#                         99,
#                         113
#                     ]
#                 }
#             ],
#             "symbols": [],
#             "user_mentions": [],
#             "urls": [
#                 {
#                     "url": "https://t.co/Ctqnz8I8b8",
#                     "expanded_url": "https://twitter.com/i/web/status/1044780702942875648",
#                     "display_url": "twitter.com/i/web/status/1\u2026",
#                     "indices": [
#                         115,
#                         138
#                     ]
#                 }
#             ]
#         },
#         "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#             "id": 989860160616189952,
#             "id_str": "989860160616189952",
#             "name": "Nilesh Arnaiya",
#             "screen_name": "NileshArnaiya",
#             "location": "",
#             "description": "https://t.co/4HfDCeaGhd. Mentor at Udacity & Mentorcruise. Freelancer",
#             "url": null,
#             "entities": {
#                 "description": {
#                     "urls": [
#                         {
#                             "url": "https://t.co/4HfDCeaGhd",
#                             "expanded_url": "https://Buildawn.com",
#                             "display_url": "Buildawn.com",
#                             "indices": [
#                                 0,
#                                 23
#                             ]
#                         }
#                     ]
#                 }
#             },
#             "protected": false,
#             "followers_count": 71,
#             "friends_count": 433,
#             "listed_count": 0,
#             "created_at": "Fri Apr 27 13:33:47 +0000 2018",
#             "favourites_count": 371,
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": false,
#             "verified": false,
#             "statuses_count": 78,
#             "lang": null,
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "F5F8FA",
#             "profile_background_image_url": null,
#             "profile_background_image_url_https": null,
#             "profile_background_tile": false,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/1185867120904531969/dSen0J5t_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1185867120904531969/dSen0J5t_normal.jpg",
#             "profile_link_color": "1DA1F2",
#             "profile_sidebar_border_color": "C0DEED",
#             "profile_sidebar_fill_color": "DDEEF6",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "has_extended_profile": true,
#             "default_profile": true,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none"
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "is_quote_status": false,
#         "retweet_count": 1,
#         "favorite_count": 1,
#         "favorited": false,
#         "retweeted": false,
#         "possibly_sensitive": false,
#         "lang": "en"
#     }
# ]

# %%
from nltk.tokenize import word_tokenize
import nltk
nltk.download('punkt')

 
tweet = 'RT @marcobonzanini: just an example! :D http://example.com #NLP'
print(word_tokenize(tweet))
# ['RT', '@', 'marcobonzanini', ':', 'just', 'an', 'example', '!', ':', 'D', 'http', ':', '//example.com', '#', 'NLP']
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# ['RT', '@', 'marcobonzanini', ':', 'just', 'an', 'example', '!', ':', 'D', 'http', ':', '//example.com', '#', 'NLP']

# %%
import re
 
emoticons_str = r"""
    (?:
        [:=;] # Eyes
        [oO\-]? # Nose (optional)
        [D\)\]\(\]/\\OpP] # Mouth
    )"""
 
regex_str = [
    emoticons_str,
    r'<[^>]+>', # HTML tags
    r'(?:@[\w_]+)', # @-mentions
    r"(?:\#+[\w_]+[\w\'_\-]*[\w_]+)", # hash-tags
    r'http[s]?://(?:[a-z]|[0-9]|[$-_@.&amp;+]|[!*\(\),]|(?:%[0-9a-f][0-9a-f]))+', # URLs
 
    r'(?:(?:\d+,?)+(?:\.?\d+)?)', # numbers
    r"(?:[a-z][a-z'\-_]+[a-z])", # words with - and '
    r'(?:[\w_]+)', # other words
    r'(?:\S)' # anything else
]
    
tokens_re = re.compile(r'('+'|'.join(regex_str)+')', re.VERBOSE | re.IGNORECASE)
emoticon_re = re.compile(r'^'+emoticons_str+'$', re.VERBOSE | re.IGNORECASE)
 
def tokenize(s):
    return tokens_re.findall(s)
 
def preprocess(s, lowercase=False):
    tokens = tokenize(s)
    if lowercase:
        tokens = [token if emoticon_re.search(token) else token.lower() for token in tokens]
    return tokens
 
tweet = 'RT @marcobonzanini: just an example! :D http://example.com #NLP'
print(preprocess(tweet))
# Out:
# ['RT', '@marcobonzanini', ':', 'just', 'an', 'example', '!', ':D', 'http://example.com', '#NLP']
